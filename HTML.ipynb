# %% [markdown]
# # html
#  - `collection of list of dataframes`

# %%
import pandas as pd

# %%
df1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_schemes_of_the_government_of_India")

# %%
len(df1)
# Out:
# 3

# %%
df1[0]
# Out:
#                                        Scheme[note 1]  \
# 0                                     Agnipath Scheme
# 1            Mahila Samman Savings Certificate (MSSC)
# 2   PM Poshan Shakti Nirman Abhiyaan (PM-POSHAN, P...
# 3   Strengthening Teaching-Learning and Results fo...
# 4   Svamitva Yojana (Survey of Villages Abadi and ...
# ..                                                ...
# 92                                       Urea subsidy
# 93              Integrated Child Development Services
# 94                                       Food subsidy
# 95                            National Service Scheme
# 96                                   Kerosene subsidy
#
#                             CS/CSS                Lead Ministry  \
# 0   CS implemented on 14 June 2022  Ministry of Defence (India)
# 1                                -                            -
# 2                              CSS                        MoWCD
# ...

# %%
df1[1]
# Out:
#                       vteGovernment schemes in India  \
# 0  List of schemes Welfare schemes for women Pove...
# 1                                             Active
# 2                                            Schemes
# 3                                           Missions
# 4                                           Projects
# 5                                          Campaigns
# 6                                           Identity
# 7                                              State
# 8                                    Closed/subsumed
# 9                                            Schemes
#
#                     vteGovernment schemes in India.1
# 0  List of schemes Welfare schemes for women Pove...
# 1                                             Active
# 2  Antyodaya Anna Atal Pension Ayushman Bharat Be...
# 3  Rejuvenation and Urban Transformation Indradha...
# 4  Agriculture MMP Bharatmala Indian Rivers Inter...
# 5  Accessible India Campaign Digital India Make i...
# ...

# %%
df1[2]
# Out:
#                     vte Premiership of Narendra Modi  \
# 0  Premiership Timeline First ministry Second min...
# 1                                          Campaigns
# 2                                    National policy
# 3                                       Legislations
# 4                                     Foreign policy
# 5                                  Category  Commons
#
#                   vte Premiership of Narendra Modi.1  \
# 0  Premiership Timeline First ministry Second min...
# 1  2014 elections primaries 2014 campaign Achhe D...
# 2  Social welfare policy and rural schemes Adarsh...
# 3  Laws 2015 Repealing and Amending Act 2015 Seco...
# 4  Asian Act East Middle Eastern South Asian SAGA...
# 5                                  Category  Commons
#
#                   vte Premiership of Narendra Modi.2
# 0  Premiership Timeline First ministry Second min...
# 1                                                NaN
# 2                                                NaN
# ...

# %% [markdown]
# # match atttribute

# %%
df2= pd.read_html("https://en.wikipedia.org/wiki/List_of_schemes_of_the_government_of_India",match='Food subsidy')

# %%
len(df2)
# Out:
# 1

# %%
df2[0]
# Out:
#                                        Scheme[note 1]  \
# 0                                     Agnipath Scheme
# 1            Mahila Samman Savings Certificate (MSSC)
# 2   PM Poshan Shakti Nirman Abhiyaan (PM-POSHAN, P...
# 3   Strengthening Teaching-Learning and Results fo...
# 4   Svamitva Yojana (Survey of Villages Abadi and ...
# ..                                                ...
# 92                                       Urea subsidy
# 93              Integrated Child Development Services
# 94                                       Food subsidy
# 95                            National Service Scheme
# 96                                   Kerosene subsidy
#
#                             CS/CSS                Lead Ministry  \
# 0   CS implemented on 14 June 2022  Ministry of Defence (India)
# 1                                -                            -
# 2                              CSS                        MoWCD
# ...
