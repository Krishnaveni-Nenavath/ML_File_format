# %% [markdown]
# # `API request`

# %%
import requests

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/8733/career"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
import pandas as pd

# %%
data = response.json() 
data
# Out:
# {'values': [{'name': 't20',
#    'debut': 'vs Zimbabwe,  2016-06-18, Harare Sports Club',
#    'lastPlayed': 'vs England,  2022-11-10, Adelaide Oval'},
#   {'name': 'test',
#    'debut': 'vs Australia,  2014-12-26, Melbourne Cricket Ground',
#    'lastPlayed': 'vs New Zealand,  2024-10-16, M.Chinnaswamy Stadium'},
#   {'name': 'odi',
#    'debut': 'vs Zimbabwe,  2016-06-11, Harare Sports Club',
#    'lastPlayed': 'vs Sri Lanka,  2024-08-04, R.Premadasa Stadium'},
#   {'name': 'ipl',
#    'debut': 'vs Kolkata Knight Riders,  2013-04-11, M.Chinnaswamy Stadium',
#    'lastPlayed': 'vs Mumbai Indians,  2024-05-17, Wankhede Stadium'},
#   {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}],
#  'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com',
#   'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}}

# %%
data.keys() #level one keys
# Out:
# dict_keys(['values', 'appIndex'])

# %% [markdown]
# # `cricter - 1`

# %%
df = pd.json_normalize(data,record_path="values",meta=[["appIndex","seoTitle"]])

# %%
df
# Out:
#    name                                              debut  \
# 0   t20       vs Zimbabwe,  2016-06-18, Harare Sports Club
# 1  test  vs Australia,  2014-12-26, Melbourne Cricket G...
# 2   odi       vs Zimbabwe,  2016-06-11, Harare Sports Club
# 3   ipl  vs Kolkata Knight Riders,  2013-04-11, M.Chinn...
# 4    cl                                         Not played
#
#                                           lastPlayed  \
# 0             vs England,  2022-11-10, Adelaide Oval
# 1  vs New Zealand,  2024-10-16, M.Chinnaswamy Sta...
# 2     vs Sri Lanka,  2024-08-04, R.Premadasa Stadium
# 3   vs Mumbai Indians,  2024-05-17, Wankhede Stadium
# 4                                         Not played
#
#                             appIndex.seoTitle
# 0  KL Rahul Profile - Cricbuzz | Cricbuzz.com
# 1  KL Rahul Profile - Cricbuzz | Cricbuzz.com
# 2  KL Rahul Profile - Cricbuzz | Cricbuzz.com
# 3  KL Rahul Profile - Cricbuzz | Cricbuzz.com
# 4  KL Rahul Profile - Cricbuzz | Cricbuzz.com

# %% [markdown]
# #   `cricter - 2`

# %%
url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/1413/career"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
data2 = response.json() 
data2
# Out:
# {'values': [{'name': 't20',
#    'debut': 'vs Zimbabwe,  2010-06-12, Harare Sports Club',
#    'lastPlayed': 'vs South Africa,  2024-06-29, Kensington Oval'},
#   {'name': 'test',
#    'debut': 'vs West Indies,  2011-06-20, Sabina Park',
#    'lastPlayed': 'vs New Zealand,  2024-11-01, Wankhede Stadium'},
#   {'name': 'odi',
#    'debut': 'vs Sri Lanka,  2008-08-18, Rangiri Dambulla International Stadium',
#    'lastPlayed': 'vs Sri Lanka,  2024-08-07, R.Premadasa Stadium'},
#   {'name': 'ipl',
#    'debut': 'vs Kolkata Knight Riders,  2008-04-18, M.Chinnaswamy Stadium',
#    'lastPlayed': 'vs Rajasthan Royals,  2024-05-22, Narendra Modi Stadium'},
#   {'name': 'cl',
#    'debut': 'vs Cape Cobras,  2009-10-08, M.Chinnaswamy Stadium',
#    'lastPlayed': 'vs Mumbai Indians,  2011-10-09, MA Chidambaram Stadium'}],
#  'appIndex': {'seoTitle': 'Virat Kohli Profile - Cricbuzz | Cricbuzz.com',
#   'webURL': 'http://www.cricbuzz.com/profiles/1413/virat-kohli'}}

# %%
data2.keys()
# Out:
# dict_keys(['values', 'appIndex'])

# %%
pd.json_normalize(data,record_path='values')
# Out:
#    name                                              debut  \
# 0   t20       vs Zimbabwe,  2016-06-18, Harare Sports Club
# 1  test  vs Australia,  2014-12-26, Melbourne Cricket G...
# 2   odi       vs Zimbabwe,  2016-06-11, Harare Sports Club
# 3   ipl  vs Kolkata Knight Riders,  2013-04-11, M.Chinn...
# 4    cl                                         Not played
#
#                                           lastPlayed
# 0             vs England,  2022-11-10, Adelaide Oval
# 1  vs New Zealand,  2024-10-16, M.Chinnaswamy Sta...
# 2     vs Sri Lanka,  2024-08-04, R.Premadasa Stadium
# 3   vs Mumbai Indians,  2024-05-17, Wankhede Stadium
# 4                                         Not played

# %%
pd.json_normalize(data2,record_path='values',meta =[["appIndex",'seoTitle']])
# Out:
#    name                                              debut  \
# 0   t20       vs Zimbabwe,  2010-06-12, Harare Sports Club
# 1  test           vs West Indies,  2011-06-20, Sabina Park
# 2   odi  vs Sri Lanka,  2008-08-18, Rangiri Dambulla In...
# 3   ipl  vs Kolkata Knight Riders,  2008-04-18, M.Chinn...
# 4    cl  vs Cape Cobras,  2009-10-08, M.Chinnaswamy Sta...
#
#                                           lastPlayed  \
# 0      vs South Africa,  2024-06-29, Kensington Oval
# 1      vs New Zealand,  2024-11-01, Wankhede Stadium
# 2     vs Sri Lanka,  2024-08-07, R.Premadasa Stadium
# 3  vs Rajasthan Royals,  2024-05-22, Narendra Mod...
# 4  vs Mumbai Indians,  2011-10-09, MA Chidambaram...
#
#                                appIndex.seoTitle
# 0  Virat Kohli Profile - Cricbuzz | Cricbuzz.com
# 1  Virat Kohli Profile - Cricbuzz | Cricbuzz.com
# 2  Virat Kohli Profile - Cricbuzz | Cricbuzz.com
# 3  Virat Kohli Profile - Cricbuzz | Cricbuzz.com
# ...

# %% [markdown]
# #  `cricket team india `

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
player_list = response.json() 
player_list
# Out:
# {'typeMatches': [{'matchType': 'International',
#    'seriesMatches': [{'seriesAdWrapper': {'seriesId': 8404,
#       'seriesName': 'India tour of South Africa, 2024',
#       'matches': [{'matchInfo': {'matchId': 100384,
#          'seriesId': 8404,
#          'seriesName': 'India tour of South Africa, 2024',
#          'matchDesc': '4th T20I',
#          'matchFormat': 'T20',
#          'startDate': '1731682800000',
#          'endDate': '1731695400000',
#          'state': 'Complete',
#          'status': 'India won by 135 runs',
#          'team1': {'teamId': 2,
#           'teamName': 'India',
#           'teamSName': 'IND',
#           'imageId': 172115},
#          'team2': {'teamId': 11,
#           'teamName': 'South Africa',
#           'teamSName': 'RSA',
#           'imageId': 172126},
#          'venueInfo': {'id': 88,
#           'ground': 'The Wanderers Stadium',
#           'city': 'Johannesburg',
#           'timezone': '+02:00',
# ...

# %%
player_list.keys()
# Out:
# dict_keys(['typeMatches', 'filters', 'appIndex', 'responseLastUpdated', 'contentFilters'])

# %%
pd.json_normalize(player_list)
# Out:
#                                          typeMatches responseLastUpdated  \
# 0  [{'matchType': 'International', 'seriesMatches...          1732097336
#
#                                       contentFilters  \
# 0  [{'filterId': 'fantasy', 'filterName': 'Fantas...
#
#                           filters.matchType  \
# 0  [International, League, Domestic, Women]
#
#                                   appIndex.seoTitle  \
# 0  Live Cricket Score - Scorecard and Match Results
#
#                          appIndex.webURL
# 0  www.cricbuzz.com/live-cricket-scores/

# %% [markdown]
# #  Task

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/10453/career"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
data11 = response.json() 
data11
# Out:
# {'values': [{'name': 't20',
#    'debut': 'vs Afghanistan,  2015-07-25, Castle Avenue',
#    'lastPlayed': 'vs Netherlands,  2024-11-16, Al Amerat Cricket Ground (Ministry Turf 1)'},
#   {'name': 'test', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'odi',
#    'debut': 'vs Namibia,  2019-04-27, Wanderers Cricket Ground',
#    'lastPlayed': 'vs Netherlands,  2024-11-11, Al Amerat Cricket Ground (Ministry Turf 1)'},
#   {'name': 'ipl', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}],
#  'appIndex': {'seoTitle': 'Jatinder Singh Profile - Cricbuzz | Cricbuzz.com',
#   'webURL': 'http://www.cricbuzz.com/profiles/10453/jatinder-singh'}}

# %%
data11.keys()
# Out:
# dict_keys(['values', 'appIndex'])

# %%
df1 = pd.json_normalize(data11,record_path='values',meta=[['appIndex','seoTitle']]) 
df1
# Out:
#    name                                              debut  \
# 0   t20         vs Afghanistan,  2015-07-25, Castle Avenue
# 1  test                                         Not played
# 2   odi  vs Namibia,  2019-04-27, Wanderers Cricket Ground
# 3   ipl                                         Not played
# 4    cl                                         Not played
#
#                                           lastPlayed  \
# 0  vs Netherlands,  2024-11-16, Al Amerat Cricket...
# 1                                         Not played
# 2  vs Netherlands,  2024-11-11, Al Amerat Cricket...
# 3                                         Not played
# 4                                         Not played
#
#                                   appIndex.seoTitle
# 0  Jatinder Singh Profile - Cricbuzz | Cricbuzz.com
# 1  Jatinder Singh Profile - Cricbuzz | Cricbuzz.com
# 2  Jatinder Singh Profile - Cricbuzz | Cricbuzz.com
# 3  Jatinder Singh Profile - Cricbuzz | Cricbuzz.com
# ...

# %%
df1['appIndex.seoTitle']= df3['appIndex.seoTitle'].str.split('-')[0][0] 
df1['appIndex.seoTitle']
# Out:
# 0    Mehran Khan Profile
# 1    Mehran Khan Profile
# 2    Mehran Khan Profile
# 3    Mehran Khan Profile
# 4    Mehran Khan Profile
# Name: appIndex.seoTitle, dtype: object

# %%
df1.to_csv(r"C:\Users\krish\Downloads\crickter1.csv",mode='x')

# %% [markdown]
# # `second crickter`

# %%
url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/10464/career"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)A

# %%
response
# Out:
# <Response [200]>

# %%
data22 = response.json() 
data22
# Out:
# {'values': [{'name': 't20',
#    'debut': 'vs Afghanistan,  2015-07-25, Castle Avenue',
#    'lastPlayed': 'vs Netherlands,  2024-11-16, Al Amerat Cricket Ground (Ministry Turf 1)'},
#   {'name': 'test', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'odi',
#    'debut': 'vs Scotland,  2024-07-16, Forthill',
#    'lastPlayed': 'vs Canada,  2024-09-26, Maple Leaf North-West Ground'},
#   {'name': 'ipl', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}],
#  'appIndex': {'seoTitle': 'Mehran Khan Profile - Cricbuzz | Cricbuzz.com',
#   'webURL': 'http://www.cricbuzz.com/profiles/10464/mehran-khan'}}

# %%
data22.keys()
# Out:
# dict_keys(['values', 'appIndex'])

# %%
df2 = pd.json_normalize(data22)

# %%
df2= pd.json_normalize(data22,record_path='values',meta=[['appIndex','seoTitle']])  
df2
# Out:
#    name                                       debut  \
# 0   t20  vs Afghanistan,  2015-07-25, Castle Avenue
# 1  test                                  Not played
# 2   odi          vs Scotland,  2024-07-16, Forthill
# 3   ipl                                  Not played
# 4    cl                                  Not played
#
#                                           lastPlayed  \
# 0  vs Netherlands,  2024-11-16, Al Amerat Cricket...
# 1                                         Not played
# 2  vs Canada,  2024-09-26, Maple Leaf North-West ...
# 3                                         Not played
# 4                                         Not played
#
#                                appIndex.seoTitle
# 0  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 1  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 2  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 3  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 4  Mehran Khan Profile - Cricbuzz | Cricbuzz.com

# %%
df2['appIndex.seoTitle']= df3['appIndex.seoTitle'].str.split('-')[0][0] 
df2['appIndex.seoTitle']
# Out:
# 0    Mehran Khan Profile
# 1    Mehran Khan Profile
# 2    Mehran Khan Profile
# 3    Mehran Khan Profile
# 4    Mehran Khan Profile
# Name: appIndex.seoTitle, dtype: object

# %%
df2.to_csv(r"C:\Users\krish\Downloads\cricter2.csv",mode='x')

# %% [markdown]
# # `third cricter`

# %%
url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/10456/career"

headers = {
	"x-rapidapi-key": "f07fa5fcc2msheae11b55feb1ebbp1f9db5jsn427d5863f248",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
data3 = response.json() 
data3
# Out:
# {'values': [{'name': 't20',
#    'debut': 'vs Afghanistan,  2015-07-25, Castle Avenue',
#    'lastPlayed': 'vs Afghanistan,  2015-11-29, Sheikh Zayed Stadium'},
#   {'name': 'test', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'odi', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'ipl', 'debut': 'Not played', 'lastPlayed': 'Not played'},
#   {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}],
#  'appIndex': {'seoTitle': 'Zeeshan Siddiqui Profile - Cricbuzz | Cricbuzz.com',
#   'webURL': 'http://www.cricbuzz.com/profiles/10456/zeeshan-siddiqui'}}

# %%
df3= pd.json_normalize(data22,record_path='values',meta=[['appIndex','seoTitle']])

# %%
df3
# Out:
#    name                                       debut  \
# 0   t20  vs Afghanistan,  2015-07-25, Castle Avenue
# 1  test                                  Not played
# 2   odi          vs Scotland,  2024-07-16, Forthill
# 3   ipl                                  Not played
# 4    cl                                  Not played
#
#                                           lastPlayed  \
# 0  vs Netherlands,  2024-11-16, Al Amerat Cricket...
# 1                                         Not played
# 2  vs Canada,  2024-09-26, Maple Leaf North-West ...
# 3                                         Not played
# 4                                         Not played
#
#                                appIndex.seoTitle
# 0  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 1  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 2  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 3  Mehran Khan Profile - Cricbuzz | Cricbuzz.com
# 4  Mehran Khan Profile - Cricbuzz | Cricbuzz.com

# %%
df3.columns
# Out:
# Index(['name', 'debut', 'lastPlayed', 'appIndex.seoTitle'], dtype='object')

# %%
df3['appIndex.seoTitle']= df3['appIndex.seoTitle'].str.split('-')[0][0] 
df3['appIndex.seoTitle']
# Out:
# 0    Mehran Khan Profile
# 1    Mehran Khan Profile
# 2    Mehran Khan Profile
# 3    Mehran Khan Profile
# 4    Mehran Khan Profile
# Name: appIndex.seoTitle, dtype: object

# %%
df3.to_csv(r"C:\Users\krish\Downloads\cricter3.csv",mode='x')

# %%
df3
# Out:
#    name                                       debut  \
# 0   t20  vs Afghanistan,  2015-07-25, Castle Avenue
# 1  test                                  Not played
# 2   odi          vs Scotland,  2024-07-16, Forthill
# 3   ipl                                  Not played
# 4    cl                                  Not played
#
#                                           lastPlayed     appIndex.seoTitle
# 0  vs Netherlands,  2024-11-16, Al Amerat Cricket...  Mehran Khan Profile
# 1                                         Not played  Mehran Khan Profile
# 2  vs Canada,  2024-09-26, Maple Leaf North-West ...  Mehran Khan Profile
# 3                                         Not played  Mehran Khan Profile
# 4                                         Not played  Mehran Khan Profile
